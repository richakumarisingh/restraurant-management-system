# %%
from PyQt5 import QtWidgets,uic
import random
import time
s=""
res=[]
opr=[]
drk=[40,45,40,30,60,25,35]
wish=[]
apt=[40,45,80,30,60,50,90]
nn=[90,85,70,40,60,60,67]
vg=[90,90,60,60,60,70,45]
bd=[40,45,40,30,30,45,35]
rc=[40,45,40,30,60,25,35]
ds=[80,95,40,70,60,25,35]
again={'d':0,'a':0,'nn':0,'v':0,'b':0,'r':0,'ds':0}
grd=[]
maha=[]
wat=''
def myadd():
    global s
    s=s+'+'
    print(hel.input.setText(s))
    
def mymul(): 
    global s
    s=s+'*'
    print(hel.input.setText(s))

def mydiv():
    global s
    s=s+'/'
    print(hel.input.setText(s))
    

def mysub():
    global s
    s=s+'-'
    print(hel.input.setText(s))
    
    
def eq():
    global s,opr,res
    def do(st):                           # st='1+5*334/7'
        global res
        if '+' in st:                       #q=[1  ,  5*334/7]
            q=st.split('+')

            for k in q:                         #k=1
                do(str(k))                           
        elif '-' in st:
            q=st.split('-')

            for k in q:
                do(str(k))  
        elif '*' in st:
            q=st.split('*')

            for k in q:
                do(str(k))  
        elif '/' in st:
            q=st.split('/')

            for k in q:
                do(str(k))  
        else:
            res.append(int(st))



    def reco(o):                           # st='1+5*334/7'
        global opr
        for j in o:
            if j=='+':                       #q=[1  ,  5*334/7]
                opr.append('+')                          
            elif j=='-':
                opr.append('-')  
            elif j=='*':
                opr.append('*') 
            elif j=='/':
                opr.append('/')  
    do(s)
    reco(s)

   
    pos=0
    ans=0
    for i in opr:
            if i=='+':
                if pos==0:
                    ans=res[pos]+res[pos+1]
                    
                else:
                    ans=ans+res[pos+1]
                
            elif i =='-':
                if pos==0:
                    ans=res[pos]-res[pos+1]
                    
                else:
                    ans=ans-res[pos+1]
                
            elif i=='*':
                if pos==0:
                    ans=res[pos]*res[pos+1]
                    
                else:
                    ans=ans*res[pos+1]
                    
            elif i =='/':
                if pos==0:
                    ans=res[pos]/res[pos+1]
                    
                else:
                    ans=ans/res[pos+1]
                    
            pos=pos+1
    print(hel.input.setText(str(ans)))
    s=str(ans)
    res=[]
    opr=[]
    
def dott():
    global s
    s=s+'.'
    print(hel.input.setText(s))
def can():
    global s,res,opr
    s=""
    res=[]
    opr=[]
    print(hel.input.setText(s))
def set0():
    global s
    s=s+'0'
    print(hel.input.setText(s))
def set1():
    global s
    s=s+'1'
    print(hel.input.setText(s))
def set2():
    global s
    s=s+'2'
    print(hel.input.setText(s))
def set3():
    global s
    s=s+'3'
    print(hel.input.setText(s))    
def set4():
    global s
    s=s+'4'
    print(hel.input.setText(s))
def set5():
    global s
    s=s+'5'
    print(hel.input.setText(s))
def set6():
    global s
    s=s+'6'
    print(hel.input.setText(s))
def set7():
    global s
    s=s+'7'
    print(hel.input.setText(s))
def set8():
    global s
    s=s+'8'
    print(hel.input.setText(s))
def set9():
    global s
    s=s+'9'
    print(hel.input.setText(s))
    
def remo():
    global s
    s=s[:(len(s))-1]
    print(hel.input.setText(s))
    
def drink():
    global wat
    wat='d'
    hel.qn.setText('          Drinks')
    print(hel.tb.setText('   --40 Rs               Sweet Lassi\n\n   --45 Rs               Mango lassi\n\n   --40 Rs               Salted Lassi\n\n   --30 Rs               Soda\n\n   --60 Rs               Badam shake\n\n   --25 Rs               Tea\n\n   --35 Rs               Coffee'))
def cleann():
    
    hel.q1.setText(" ")
    hel.q2.setText(" ")
    hel.q3.setText(" ")
    hel.q4.setText(" ")
    hel.q5.setText(" ")
    hel.q6.setText(" ")
    hel.q7.setText(" ")
    hel.t1.setText('')
    hel.t2.setText('')
    hel.t3.setText('')
    hel.t4.setText('')
    hel.t5.setText('')
    hel.t6.setText('')
    hel.t7.setText('')
def appe():   
    cleann()
    global wat
    wat='a'
    hel.qn.setText('          Appetizers')
    print(hel.tb.setText('   --40 Rs               Samosa\n\n   --45 Rs               Pakoda\n\n   --80 Rs               Chikken Tikka\n\n   --30 Rs               Spring roll\n\n   --60 Rs               Gobi manchurian\n\n   --50 Rs               Momos\n\n   --90 Rs               Chiken manchurian'))

def non():
    global wat
    cleann()
    wat='nn'
    hel.qn.setText('              Non veg')
    print(hel.tb.setText('   --90 Rs               Chiken korma\n\n   --85 Rs               Chiken kadai\n\n   --70 Rs               Chiken curry\n\n   --40 Rs               Egg curry\n\n --60 Rs               Fish curry\n\n   --60 Rs               Prawn\n\n   --67 Rs               Goat'))
def veg():
    cleann()
    global wat
    hel.qn.setText('         Veg')
    wat='v'
    print(hel.tb.setText('   --90 Rs               Shahi paneer\n\n   --90 Rs               Mutter paneer\n\n   --60 Rs               Aloo gobhi\n\n   --60 Rs               Dal tadka\n\n --60 Rs               Paneer makhni\n\n   --70 Rs               Chole\n\n   --45 Rs               Saag'))

def bread():
    cleann()
    global wat
    hel.qn.setText('            Breads')
    wat='b'
    print(hel.tb.setText('   --40 Rs               Butter naan\n\n   --45 Rs               Kheema naan\n\n   --40 Rs               Onion kulcha\n\n   --30 Rs               Roti\n\n   --30 Rs               Lachha paratha\n\n   --45 Rs               Aloo paratha\n\n   --35 Rs               Gobi paratha'))
def rice():
    cleann()
    hel.qn.setText('            Rice')
    global wat
    wat='r'
    print(hel.tb.setText('   --40 Rs               Gobi rice\n\n   --45 Rs               Pulao\n\n   --40 Rs               Jeera rice\n\n   --30 Rs               Egg biryani\n\n   --60 Rs               Basmati rice\n\n   --25 Rs               Bombay pulao\n\n   --35 Rs               Gosht biryani'))
def dessert():
    cleann()
    global wat
    hel.qn.setText('            Desserts')
    wat='ds'
    print(hel.tb.setText('   --80 Rs               Rasmalayi\n\n   --95 Rs               Pineapple pudding\n\n   --40 Rs               Kulfi\n\n   --70 Rs               Gajar halwa\n\n   --60 Rs               Gulab jamun\n\n   --25 Rs               Caramel custurd\n\n   --35 Rs               Rasgulla'))

def canord():
    global grd,maha,wish
    grd.clear()
    maha.clear()
    wat=''
    wish.clear()
    cleann()
    hel.lv.clear()
def calc(ls):
    tt=[]
    grd=[]
    global maha
    hel.gt.setText(' ')
    if hel.q1.text()!='':
        try:
            tt.append(int(hel.q1.text()))
        except:
            tt.append(0)
            hel.q1.setText('0')
    else:
        tt.append(0)
        hel.q1.setText('0')
        
    if hel.q2.text()!='':
        try:
            tt.append(int(hel.q2.text()))
        except:
            tt.append(0)
            hel.q2.setText('0') 
    else:
        tt.append(0)
        hel.q2.setText('0')
    if hel.q3.text()!='':
        try:
            tt.append(int(hel.q3.text()))
        except:
            tt.append(0)
            hel.q3.setText('0')
    else:
        tt.append(0)
        hel.q3.setText('0')
    
    if hel.q4.text()!='':
        try:
            tt.append(int(hel.q4.text()))
        except:
            tt.append(0)
            hel.q4.setText('0')
    else:
        tt.append(0)
        hel.q4.setText('0')
    
    if hel.q5.text()!='':
        try:
            tt.append(int(hel.q5.text()))
        except:
            tt.append(0)
            hel.q5.setText('0')
    else:
        tt.append(0)
        hel.q5.setText('0')
    
    if hel.q6.text()!='':
        try:
            tt.append(int(hel.q6.text()))
        except:
            tt.append(0)
            hel.q6.setText('0')
    else:
        tt.append(0)
        hel.q6.setText('0')
    
    if hel.q7.text()!='':
        try:
            tt.append(int(hel.q7.text()))
        except:
            tt.append(0)
            hel.q7.setText('0')
    else:
        tt.append(0)
        hel.q7.setText('0')
    
 
    
        
    for i in range(7):
        grd.append(ls[i]*tt[i])
        
    hel.t1.setText(str(grd[0]))
    hel.t2.setText(str(grd[1]))
    hel.t3.setText(str(grd[2]))
    hel.t4.setText(str(grd[3]))
    hel.t5.setText(str(grd[4]))
    hel.t6.setText(str(grd[5]))
    hel.t7.setText(str(grd[6]))
    maha.append(sum(grd))
    hel.gt.setText(str(sum(grd)))
    hel.ttt.setText(str(sum(maha)))
        
def subm():                                                
    global grd,maha,dq,drk,apt,nn,vg,bd,rc,ds,wish,again
    
    if (wat=='d'):
        again['d']=again['d']+1
        if (again['d']>1):
            hel.err.setText('Already ordered !!!')
        else:
            calc(drk)
            wish.append('')
            wish.append('')
            wish.append('                 Drinnks')
            if (int(hel.q1.text())>0):
                wish.append('Sweet Lassi')
            if (int(hel.q2.text())>0):
                wish.append('Mango lassi')
            if (int(hel.q3.text())>0):
                wish.append('Salted Lassi')
            if (int(hel.q4.text())>0):
                wish.append('Soda')
            if (int(hel.q5.text())>0):
                wish.append('Badam shake')
            if (int(hel.q6.text())>0):
                wish.append('Tea')
            if (int(hel.q7.text())>0):
                wish.append('Coffee')
            k="\n"
            for i in wish:
                k=k+i
                hel.lv.addItem(i)

    if (wat=='a'): 
        again['a']=again['a']+1
        if (again['a']>1):
            hel.err.setText('Already ordered !!!')
        else:
            calc(apt)
            wish.clear()

            wish.append('')
            wish.append('                 Appetizers')
            if (int(hel.q1.text())>0):
                wish.append('Samosa')
            if (int(hel.q2.text())>0):
                wish.append('Pakoda')
            if (int(hel.q3.text())>0):
                wish.append('Chikken Tikka')
            if (int(hel.q4.text())>0):
                wish.append('Spring roll')
            if (int(hel.q5.text())>0):
                wish.append('Gobi manchurian')
            if (int(hel.q6.text())>0):
                wish.append('Momos')
            if (int(hel.q7.text())>0):
                wish.append('Chiken manchurian')
            k="\n"
            for i in wish:
                k=k+i
                hel.lv.addItem(i)
    if (wat=='nn'): 
        again['nn']=again['nn']+1
        if (again['nn']>1):
            hel.err.setText('Already ordered !!!')
        else:
            calc(nn)
            wish.clear()
            wish.append('')
            wish.append('                 Non-Veg')
            if (int(hel.q1.text())>0):
                wish.append('Chiken korma')
            if (int(hel.q2.text())>0):
                wish.append('Chiken kadai')
            if (int(hel.q3.text())>0):
                wish.append('Chiken curry')
            if (int(hel.q4.text())>0):
                wish.append('Egg curry')
            if (int(hel.q5.text())>0):
                wish.append('Fish curry')
            if (int(hel.q6.text())>0):
                wish.append('Prawn')
            if (int(hel.q7.text())>0):
                wish.append('Goat')
            k="\n"
            for i in wish:
                k=k+i
                hel.lv.addItem(i)
    if (wat=='v'):
        again['v']=again['v']+1
        if (again['v']>1):
            hel.err.setText('Already ordered !!!')
        else:
            calc(vg)
            wish.clear()
            wish.append('')
            wish.append('                   Veg')
            if (int(hel.q1.text())>0):
                wish.append('Shahi paneer')
            if (int(hel.q2.text())>0):
                wish.append('Mutter paneer')
            if (int(hel.q3.text())>0):
                wish.append('Aloo gobhi')
            if (int(hel.q4.text())>0):
                wish.append('Dal tadka')
            if (int(hel.q5.text())>0):
                wish.append('Paneer makhni')
            if (int(hel.q6.text())>0):
                wish.append('Chole')
            if (int(hel.q7.text())>0):
                wish.append('Saag')
            k="\n"
            for i in wish:
                k=k+i
                hel.lv.addItem(i)
    if (wat=='b'):  
        again['b']=again['b']+1
        if (again['b']>1):
            hel.err.setText('Already ordered !!!')
        else:
            calc(bd)
            wish.clear()
            wish.append('')
            wish.append('                   Bread')
            if (int(hel.q1.text())>0):
                wish.append('Butter naan')
            if (int(hel.q2.text())>0):
                wish.append('Kheema naan')
            if (int(hel.q3.text())>0):
                wish.append('Onion kulcha')
            if (int(hel.q4.text())>0):
                wish.append('Roti')
            if (int(hel.q5.text())>0):
                wish.append('Lachha paratha')
            if (int(hel.q6.text())>0):
                wish.append('Aloo paratha')
            if (int(hel.q7.text())>0):
                wish.append('Gobi paratha')
            k="\n"
            for i in wish:
                k=k+i
                hel.lv.addItem(i)
    if (wat=='r'):  
        again['r']=again['r']+1
        if (again['r']>1):
            hel.err.setText('Already ordered !!!')
        else:
            calc(rc)
            wish.clear()
            wish.append('')
            wish.append('                     Rice')
            if (int(hel.q1.text())>0):
                wish.append('Gobi rice')
            if (int(hel.q2.text())>0):
                wish.append(' Pulao')
            if (int(hel.q3.text())>0):
                wish.append('Jeera rice')
            if (int(hel.q4.text())>0):
                wish.append('Egg biryani')
            if (int(hel.q5.text())>0):
                wish.append('Basmati rice')
            if (int(hel.q6.text())>0):
                wish.append('Bombay pulao')
            if (int(hel.q7.text())>0):
                wish.append('Gosht biryani ')
            k="\n"
            for i in wish:
                k=k+i
                hel.lv.addItem(i)
    if (wat=='ds'):
        again['ds']=again['ds']+1
        if (again['ds']>1):
            hel.err.setText('Already ordered !!!')
        else:
            calc(ds)
            wish.clear()
            wish.append('')
            wish.append('                 Dessert')
            if (int(hel.q1.text())>0):
                wish.append('Rasmalayi')
            if (int(hel.q2.text())>0):
                wish.append(' Pineapple pudding')
            if (int(hel.q3.text())>0):
                wish.append('Kulfi')
            if (int(hel.q4.text())>0):
                wish.append('Gajar halwa')
            if (int(hel.q5.text())>0):
                wish.append('Gulab jamun')
            if (int(hel.q6.text())>0):
                wish.append('Caramel custurd')
            if (int(hel.q7.text())>0):
                wish.append('Rasgulla ')
            k="\n"
            for i in wish:
                k=k+i
                hel.lv.addItem(i)
             

    
            
app=QtWidgets.QApplication([])
hel=uic.loadUi('restau.ui')
l='Today : ' +time.asctime(time.localtime(time.time()))
hel.lb.setText(l)
hel.pb0.clicked.connect(set0)
hel.pb1.clicked.connect(set1)
hel.pb2.clicked.connect(set2)
hel.pb3.clicked.connect(set3)
hel.pb4.clicked.connect(set4)
hel.pb5.clicked.connect(set5)
hel.pb6.clicked.connect(set6)

hel.pb7.clicked.connect(set7)
hel.pb8.clicked.connect(set8)
hel.pb9.clicked.connect(set9)
hel.add.clicked.connect(myadd)
hel.dot.clicked.connect(dott)
hel.sub.clicked.connect(mysub)
hel.mul.clicked.connect(mymul)
hel.div.clicked.connect(mydiv)
hel.equal.clicked.connect(eq)
hel.cancel.clicked.connect(can)
hel.deloo.clicked.connect(remo)

hel.dr.clicked.connect(drink)
hel.ap.clicked.connect(appe)
hel.no.clicked.connect(non)
hel.ve.clicked.connect(veg)
hel.br.clicked.connect(bread)
hel.ri.clicked.connect(rice)
hel.de.clicked.connect(dessert)
hel.canor.clicked.connect(canord)
hel.submit.clicked.connect(subm)
hel.show()
app.exec()
# Out:
# None
# None
# None
# 0
